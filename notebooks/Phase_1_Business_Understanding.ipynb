# %% [markdown]
# # Phase 1: Business Understanding
#
# **CRISP-DM Phase Description:**
# This phase focuses on understanding the project objectives and requirements from a business perspective, then converting this knowledge into a data mining problem definition and a preliminary plan designed to achieve the objectives.
#
# ---

# %%
"""
Predicting Student Success & Dropout
Dataset: Predict Students' Dropout and Academic Success (UCI Machine Learning Repository / Kaggle)

Key Features:
    1. Demographics: Marital status, Age at enrollment.
    2. Socio-Economic: Scholarship holder status, Parental education levels.
    3. Academic Performance: Application mode, Curricular units (1st & 2nd semester grades/enrollments).
    4. Target Variable: Dropout, Enrolled, or Graduate.

Research Questions:
Q1: Business Perspective (Early Intervention)
    1. Objective: Can we identify students at high risk of dropping out by the end of their 1st Semester with >80% accuracy?
    2. Goal: To proactively assign tutoring resources and prevent institutional revenue loss.
    3. Methodology Hint: This would likely involve a Binary Classification model (e.g., Random Forest or XGBoost) using only features available
        up to the end of the first semester.

Q2: Research Perspective (Socio-Economic Impact)
    1. Objective: Controlling for incoming academic grades, what is the independent marginal effect of "Scholarship Status" or "Parental Education" 
        on the probability of a student graduating?
    2. Goal: To isolate the impact of socio-economic factors from academic ability.
    3. Methodology Hint: This requires Logistic Regression or Causal Inference techniques to determine the coefficients (odds ratios) for these specific predictors while holding "Grades" constant
"""

""" 
Role: Act as a Senior Data Scientist specializing in Educational Technology (EdTech).
Task: Develop a predictive analysis plan and implementation code for the "Predict Students' Dropout and Academic Success" dataset.
Data Context: The dataset contains demographics (marital status, age), socio-economics (scholarship, parental education), and academic performance (1st and 2nd semester grades). The target variable is [Dropout, Enrolled, Graduate].
Objectives:
    - Early Intervention (Classification): Build a model using only 1st-semester data to predict dropouts with >80% accuracy.
    - Socio-Economic Impact (Inference): Use statistical modeling to determine the marginal effect of "Scholarship Status" on graduation probability, controlling for academic grades.

Output: Provide a structured Python script using Scikit-Learn or Statsmodels, including data preprocessing and a brief explanation of the results.

"""
# Out:
# ' \nRole: Act as a Senior Data Scientist specializing in Educational Technology (EdTech).\nTask: Develop a predictive analysis plan and implementation code for the "Predict Students\' Dropout and Academic Success" dataset.\nData Context: The dataset contains demographics (marital status, age), socio-economics (scholarship, parental education), and academic performance (1st and 2nd semester grades). The target variable is [Dropout, Enrolled, Graduate].\nObjectives:\n    - Early Intervention (Classification): Build a model using only 1st-semester data to predict dropouts with >80% accuracy.\n    - Socio-Economic Impact (Inference): Use statistical modeling to determine the marginal effect of "Scholarship Status" on graduation probability, controlling for academic grades.\n\nOutput: Provide a structured Python script using Scikit-Learn or Statsmodels, including data preprocessing and a brief explanation of the results.\n\n'

# %% [markdown]
# ### Task 1: Determine Business Objectives
#
# The first objective of the data analyst is to thoroughly understand, from a business perspective, what the customer really wants to accomplish. This involves:
#
# - **Background:** Identify the organisational context and the business area the project relates to.
# - **Business Objectives:** Clearly state the primary question or problem the business wants to solve.
# - **Business Success Criteria:** Define the measurable criteria that determine whether the project's outcome is considered a success from the business's point of view (e.g., "reduce customer churn by 15%", "improve prediction accuracy to 90%").
#
# **Instructions:** In the cells below, define your business objectives, background context, and success criteria as Python variables (strings or dictionaries). This ensures your business logic is documented directly in the notebook's code state.

# %%
# TODO: Define business objectives here.
# Example:
# business_objectives = {
#     "background": "Describe the organisational context and business area...",
#     "primary_objective": "What is the main business question or problem?",
#     "success_criteria": [
#         "Criterion 1: e.g., Reduce X by Y%",
#         "Criterion 2: e.g., Achieve Z accuracy"
#     ]
# }

business_objectives = {
    "background": ("""
        Higher education institutions face significant financial and operational challenges 
        due to student attrition. Dropping out not only impacts the student's long-term 
        prospects but also results in lost tuition revenue and diminished institutional 
        performance metrics. This project leverages demographic, socio-economic, and 
        academic data to understand the drivers of student success and failure in order to 
        transition from reactive student support to a proactive 'Early Warning System' (EWS). """
    ),
    "primary_objective": (""" 
        To develop a dual-purpose analytical framework that:
        (1) identifies high-risk students by the end of their first year for early intervention,
        (2) quantifies the socio-economic factors—specifically scholarship status and parental education—that 
        independently influence graduation rates."""
    ),
    "success_criteria": [
        "Criterion 1: Achieve a predictive accuracy and Recall (Sensitivity) of >80% for the 'Dropout' class using 1st-semester data.",
        "Criterion 2: Statistically isolate the marginal effect of scholarship status and parental education on graduation probability.",
        "Criterion 3: Provide actionable insights to proactively allocate tutoring and financial support resources to at-risk cohorts.",
        "Criterion 4: Reduce institutional revenue loss by identifying at least 75% of potential dropouts before the start of the 2nd semester."
    ]
}

# %%
# Display the defined objectives in a readable format
for key, value in business_objectives.items():
    print(f">> {key.upper().replace('_', ' ')}:")
    if isinstance(value, list):
        for item in value:
            print(f"   - {item}")
    else:
        print(f"   {value}")
    print()
# Out:
# >> BACKGROUND:
#
#         Higher education institutions face significant financial and operational challenges
#         due to student attrition. Dropping out not only impacts the student's long-term
#         prospects but also results in lost tuition revenue and diminished institutional
#         performance metrics. This project leverages demographic, socio-economic, and
#         academic data to understand the drivers of student success and failure in order to
#         transition from reactive student support to a proactive 'Early Warning System' (EWS).
#
# >> PRIMARY OBJECTIVE:
#
#         To develop a dual-purpose analytical framework that:
#         (1) identifies high-risk students by the end of their first year for early intervention,
#         (2) quantifies the socio-economic factors—specifically scholarship status and parental education—that
#         independently influence graduation rates.
#
# >> SUCCESS CRITERIA:
# ...

# %% [markdown]
# ---
# ### Task 2: Assess Situation
#
# This task involves a more detailed fact-finding about all of the resources, constraints, assumptions, and other factors that should be considered in determining the data analysis goal and project plan. Key areas to assess:
#
# - **Resources Inventory:** Personnel, data sources, computing resources, and software available.
# - **Requirements, Assumptions, and Constraints:** Project schedule, legal/ethical considerations, data access limitations, and budget.
# - **Risks and Contingencies:** Identify potential risks (e.g., data unavailability, quality issues, privacy concerns) and how to mitigate them.
# - **Terminology Glossary:** Define key domain-specific terms relevant to the project.
# - **Costs and Benefits:** A cost-benefit analysis of the project.
#
# **Instructions:** Document your situation assessment as a structured dictionary or set of variables.

# %%
# TODO: Assess the current situation here.
# Document resources, requirements, assumptions, constraints, and risks.
    
situation_assessment = {
    "resources": {
        "personnel": ["Lead Data Scientist", "Higher Education Domain Expert (Registrar/Academic Advisor)"],
        "data_sources": ["UCI Machine Learning Repository / Kaggle CSV"],
        "computing": "Local machine (Jupyter Notebook / VS Code) or Google Colab",
        "software": ["Python 3.10+", "pandas", "scikit-learn", "statsmodels", "seaborn", "matplotlib", "xgboost"]
    },
    "requirements": [
        "Models must be interpretable to explain intervention logic to faculty or provide Feature Importance rankings.",
        "Predictive model for Q1 must only use features available at the end of the first year.",
        "Must achieve >80% accuracy for the 'Dropout' class to be considered viable.",
        "Compliance with data privacy standards (FERPA/GDPR equivalent) for student data."
    ],
    "assumptions": [
        "Historical patterns in the dataset are representative of current student behavior.",
        "Scholarship status and parental education are accurately recorded at enrollment.",
        "Students labeled as 'Enrolled' in the dataset will eventually transition to 'Graduate' or 'Dropout'."
    ],
    "constraints": [
        "Fixed feature set (cannot collect new variables like student mental health or campus engagement).",
        "Computational limits of local hardware if performing extensive hyperparameter tuning.",
        "The dataset is a 'snapshot' in time, not a real-time data stream."
    ],
    "risks_and_contingencies": [
        {
            "risk": "Data Leakage: Using 2nd-semester grades to predict 1st-semester dropout risk.",
            "probability": "High",
            "mitigation": "Strictly partition features into 'T1' (available at start) and 'T2' (available later) sets."
        },
        {
            "risk": "Class Imbalance: Fewer dropouts than graduates may bias the model.",
            "probability": "Medium",
            "mitigation": "Use SMOTE (oversampling) or adjust class weights in the loss function or use Gradient Boosting algorithms that are robust to minor imbalance."
        },
        {
            "risk": "Algorithmic Bias: Model may unfairly penalize specific demographic groups.",
            "probability": "Medium",
            "mitigation": "Perform a fairness audit across age and marital status groups."
        }
    ],
    "terminology": {
        "Curricular Units": "The number of courses or credits a student is enrolled in or has completed.",
        "Marginal Effect": "The change in the probability of an outcome (graduation) produced by a one-unit change in a predictor (e.g., having a scholarship).",
        "At-Risk": "A student with a predicted dropout probability exceeding a specific threshold (e.g., 0.50)."
    },
    "cost_benefit": (
        "Benefit: Preventing even a 5% increase in retention saves significant tuition revenue. "
        "Cost: Development time and the cost of tutoring resources assigned to students flagged by the model."
    )
}

# %%
# Display situation assessment
import json
print(json.dumps(situation_assessment, indent=2))
# Out:
# {
#   "resources": {
#     "personnel": [
#       "Lead Data Scientist",
#       "Higher Education Domain Expert (Registrar/Academic Advisor)"
#     ],
#     "data_sources": [
#       "UCI Machine Learning Repository / Kaggle CSV"
#     ],
#     "computing": "Local machine (Jupyter Notebook / VS Code) or Google Colab",
#     "software": [
#       "Python 3.10+",
#       "pandas",
#       "scikit-learn",
#       "statsmodels",
#       "seaborn",
#       "matplotlib",
#       "xgboost"
#     ]
#   },
#   "requirements": [
#     "Models must be interpretable to explain intervention logic to faculty or provide Feature Importance rankings.",
#     "Predictive model for Q1 must only use features available at the end of the first year.",
#     "Must achieve >80% accuracy for the 'Dropout' class to be considered viable.",
#     "Compliance with data privacy standards (FERPA/GDPR equivalent) for student data."
#   ],
#   "assumptions": [
# ...

# %%
# Optional: Add any further notes or elaboration on the situation assessment

# %% [markdown]
# ---
# ### Task 3: Determine Data Mining Goals
#
# A business goal states objectives in business terminology. A data mining goal states project objectives in technical terms. This task converts the business objectives identified in Task 1 into specific, measurable data mining goals:
#
# - **Data Mining Problem Type:** Classify the problem (e.g., classification, regression, clustering, anomaly detection, association rule mining, etc.).
# - **Data Mining Goals:** State the technical objectives clearly (e.g., "Build a classification model to predict [target variable] with an F1-score ≥ 0.85").
# - **Data Mining Success Criteria:** Define the technical metrics that will be used to evaluate the model's performance (e.g., accuracy, precision, recall, RMSE, silhouette score).
#
# **Instructions:** Map your business objectives to concrete data mining goals.

# %%
data_mining_goals = {
    "problem_type": "Binary Classification (Predictive) and Logistic Regression (Inference)",
    "target_variable": "Target (Mapped to 1: Dropout, 0: Graduate/Enrolled)",
    "technical_goals": [
        "Goal 1: Transform the 3-class 'Target' into a binary 'At-Risk' label.",
        "Goal 2: Feature-engineer a 'First-Year Comprehensive' dataset, ensuring academic performance indicators from both semesters are included without leaking the final target outcome into the features."        
        "Goal 3: Train a classifier (e.g., Random Forest or XGBoost) to identify high-risk students.",
        "Goal 4: Perform a Logistic Regression to calculate Odds Ratios for Scholarship and Parental Education features."
    ],
    "success_metrics": [
        "Metric 1: Accuracy > 80% (Institutional requirement).",
        "Metric 2: Recall (Sensitivity) >= 0.80 for the 'Dropout' class—prioritizing catching every at-risk student.",
        "Metric 3: AUC-ROC >= 0.85, ensuring the model distinguishes well between classes regardless of the threshold.",
        "Metric 4: Statistical Significance (p-value < 0.05) for socio-economic coefficients to validate research findings."
    ]
}

# %%
# Display the mapping from business objectives to data mining goals
print("=" * 60)
print("BUSINESS TO DATA MINING GOAL MAPPING")
print("=" * 60)
print(f"\nBusiness Objective : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"\nTechnical Goals:")
for goal in data_mining_goals['technical_goals']:
    print(f"  - {goal}")
print(f"\nSuccess Metrics:")
for metric in data_mining_goals['success_metrics']:
    print(f"  - {metric}")
# Out:
# ...
# BUSINESS TO DATA MINING GOAL MAPPING
# ...
#
# Business Objective :
#         To develop a dual-purpose analytical framework that:
#         (1) identifies high-risk students by the end of their first year for early intervention,
#         (2) quantifies the socio-economic factors—specifically scholarship status and parental education—that
#         independently influence graduation rates.
# Problem Type       : Binary Classification (Predictive) and Logistic Regression (Inference)
# Target Variable    : Target (Mapped to 1: Dropout, 0: Graduate/Enrolled)
#
# Technical Goals:
#   - Goal 1: Transform the 3-class 'Target' into a binary 'At-Risk' label.
#   - Goal 2: Feature-engineer a 'First-Year Comprehensive' dataset, ensuring academic performance indicators from both semesters are included without leaking the final target outcome into the features.Goal 3: Train a classifier (e.g., Random Forest or XGBoost) to identify high-risk students.
# ...

# %% [markdown]
# ---
# ### Task 4: Produce Project Plan
#
# Describe the intended plan for achieving the data mining goals and thereby achieving the business goals. The plan should specify:
#
# - **Tools and Techniques:** The data mining tools (libraries, frameworks) and modelling techniques you plan to use.
# - **Project Plan / Timeline:** A step-by-step plan with estimated durations for each remaining CRISP-DM phase.
# - **Dependencies:** Any dependencies between tasks or on external factors.
# - **Initial Assessment of Tools and Techniques:** A brief justification for why the chosen tools and techniques are appropriate.
#
# **Instructions:** Outline your full project plan as a structured data object below.

# %%
project_plan = {
    "tools": [
        "pandas", "numpy", "matplotlib", "seaborn", 
        "scikit-learn", "statsmodels", "XGBoost", "imbalanced-learn"
    ],
    "techniques": [
        "Exploratory Data Analysis (EDA)", 
        "SMOTE (Synthetic Minority Over-sampling Technique)", 
        "Random Forest / XGBoost (Classification)", 
        "Logistic Regression (Inference/Odds Ratios)", 
        "Recursive Feature Elimination (RFE)",
        "SHAP (Interpretability/Explainability)"
    ],
    "timeline": [
        {"phase": "Data Understanding", "duration": "Week 1", "status": "In Progress"},
        {"phase": "Data Preparation & Cleaning", "duration": "Week 1-2", "status": "Not Started"},
        {"phase": "Feature Engineering (First-Year Feature Set)", "duration": "Week 2", "status": "Not Started"},
        {"phase": "Modeling (Q1 Prediction & Q2 Inference)", "duration": "Week 3-4", "status": "Not Started"},
        {"phase": "Evaluation & Business Validation", "duration": "Week 5", "status": "Not Started"},
        {"phase": "Final Reporting & Deployment Strategy", "duration": "Week 6", "status": "Not Started"}
    ],
    "dependencies": [
        "Full documentation of feature meanings from the UCI metadata.",
        "Definition of 'Success' threshold for the First Year (e.g., minimum grade or credit ratio).",
        "Verification that demographic features are collected legally and ethically (FERPA/GDPR)."
    ],
    "tool_justification": (
        "We selected Python for its robust ecosystem: 'scikit-learn' and 'XGBoost' provide the high-performance "
        "classification power needed for Q1, while 'statsmodels' allows for the formal p-value analysis required "
        "by Q2. 'imbalanced-learn' is critical for addressing the likely higher volume of graduates vs. dropouts."
    )
}

# %%
# Display the project plan
print("=" * 60)
print("PROJECT PLAN")
print("=" * 60)

print("\nTools:", ", ".join(project_plan['tools']) if project_plan['tools'] else "[Not yet defined]")
print("Techniques:", ", ".join(project_plan['techniques']) if project_plan['techniques'] else "[Not yet defined]")

print("\nTimeline:")
if project_plan['timeline']:
    for phase in project_plan['timeline']:
        print(f"  [{phase.get('status', 'N/A'):^12}] {phase['phase']:<25} | {phase['duration']}")
else:
    print("  [Not yet defined]")

print("\nDependencies:")
for dep in project_plan['dependencies']:
    print(f"  - {dep}")

print(f"\nTool Justification: {project_plan['tool_justification']}")
# Out:
# ...
# PROJECT PLAN
# ...
#
# Tools: pandas, numpy, matplotlib, seaborn, scikit-learn, statsmodels, XGBoost, imbalanced-learn
# Techniques: Exploratory Data Analysis (EDA), SMOTE (Synthetic Minority Over-sampling Technique), Random Forest / XGBoost (Classification), Logistic Regression (Inference/Odds Ratios), Recursive Feature Elimination (RFE), SHAP (Interpretability/Explainability)
#
# Timeline:
#   [In Progress ] Data Understanding        | Week 1
#   [Not Started ] Data Preparation & Cleaning | Week 1-2
#   [Not Started ] Feature Engineering (First-Year Feature Set) | Week 2
#   [Not Started ] Modeling (Q1 Prediction & Q2 Inference) | Week 3-4
#   [Not Started ] Evaluation & Business Validation | Week 5
#   [Not Started ] Final Reporting & Deployment Strategy | Week 6
#
# Dependencies:
#   - Full documentation of feature meanings from the UCI metadata.
#   - Definition of 'Success' threshold for the First Year (e.g., minimum grade or credit ratio).
# ...

# %%
# Optional: Summarise all Phase 1 outputs for reference in subsequent phases
print("=" * 60)
print("PHASE 1 SUMMARY: BUSINESS UNDERSTANDING")
print("=" * 60)
print(f"\nPrimary Objective  : {business_objectives['primary_objective']}")
print(f"Problem Type       : {data_mining_goals['problem_type']}")
print(f"Target Variable    : {data_mining_goals['target_variable']}")
print(f"Tools Planned      : {', '.join(project_plan['tools']) if project_plan['tools'] else 'TBD'}")
print(f"Techniques Planned : {', '.join(project_plan['techniques']) if project_plan['techniques'] else 'TBD'}")
# Out:
# ...
# PHASE 1 SUMMARY: BUSINESS UNDERSTANDING
# ...
#
# Primary Objective  :
#         To develop a dual-purpose analytical framework that:
#         (1) identifies high-risk students by the end of their first year for early intervention,
#         (2) quantifies the socio-economic factors—specifically scholarship status and parental education—that
#         independently influence graduation rates.
# Problem Type       : Binary Classification (Predictive) and Logistic Regression (Inference)
# Target Variable    : Target (Mapped to 1: Dropout, 0: Graduate/Enrolled)
# Tools Planned      : pandas, numpy, matplotlib, seaborn, scikit-learn, statsmodels, XGBoost, imbalanced-learn
# Techniques Planned : Exploratory Data Analysis (EDA), SMOTE (Synthetic Minority Over-sampling Technique), Random Forest / XGBoost (Classification), Logistic Regression (Inference/Odds Ratios), Recursive Feature Elimination (RFE), SHAP (Interpretability/Explainability)
